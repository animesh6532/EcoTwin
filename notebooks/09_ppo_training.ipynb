# %% [markdown]
# # Notebook 09: PPO Training
#
# **Purpose:** Train a Proximal Policy Optimization (PPO) agent against the validated EcoTwin environment using stable-baselines3.

# %%
import sys
import os
from pathlib import Path
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback

sys.path.append(str(Path("..").resolve()))
from backend.rl.environment import EcoTwinEnv
from backend.rl.ppo_config import get_ppo_hyperparameters
# Out:
# 2026-08-21 11:56:31,072 [INFO] EcoTwin: Logging initialized successfully
# 2026-08-21 11:56:31,074 [INFO] EcoTwin: SUMO_HOME verified: C:\Program Files (x86)\Eclipse\Sumo\

# %% [markdown]
# ### Initialize Training and Model

# %%
env = EcoTwinEnv(config={
    "scenario": "training",
    "gui": False,
    "step_length": 1.0,
    "max_steps": 1000
})

hyperparams = get_ppo_hyperparameters()
print("PPO Hyperparameters:", hyperparams)

# Instantiate stable-baselines3 PPO
model = PPO(
    policy="MlpPolicy",
    env=env,
    learning_rate=hyperparams["learning_rate"],
    n_steps=256,         # Lower n_steps for faster iteration inside notebook
    batch_size=64,
    n_epochs=hyperparams["n_epochs"],
    gamma=hyperparams["gamma"],
    gae_lambda=hyperparams["gae_lambda"],
    clip_range=hyperparams["clip_range"],
    ent_coef=hyperparams["ent_coef"],
    vf_coef=hyperparams["vf_coef"],
    max_grad_norm=hyperparams["max_grad_norm"],
    verbose=1,
    tensorboard_log="../reports/ppo_training/tb/"
)
# Out:
# PPO Hyperparameters: {'learning_rate': 0.0003, 'n_steps': 2048, 'batch_size': 64, 'n_epochs': 10, 'gamma': 0.99, 'gae_lambda': 0.95, 'clip_range': 0.2, 'ent_coef': 0.01, 'vf_coef': 0.5, 'max_grad_norm': 0.5, 'verbose': 1}
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### Train PPO Agent

# %%
# Run PPO learning for 2000 timesteps to establish baseline convergence
model.learn(total_timesteps=2000)

# Save best model
model.save("../models/ppo/best_model.zip")
env.close()
print("PPO training completed and model saved successfully.")
# Out:
# Logging to ../reports/ppo_training/tb/PPO_2
# ----------------------------
# | time/              |     |
# |    fps             | 95  |
# |    iterations      | 1   |
# |    time_elapsed    | 2   |
# |    total_timesteps | 256 |
# ----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 79           |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0053972024 |
# |    clip_fraction        | 0.00195      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00205     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.52e+04     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00819     |
# |    value_loss           | 5.11e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 3           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.000495997 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00366     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.6e+04     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00147    |
# |    value_loss           | 1.66e+05    |
# -----------------------------------------
# SUMO simulation closed.
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -2.88e+04    |
# | time/                   |              |
# |    fps                  | 61           |
# |    iterations           | 4            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0004854882 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.000959    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.64e+05     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 3.39e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | -2.88e+04     |
# | time/                   |               |
# |    fps                  | 65            |
# |    iterations           | 5             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 1280          |
# | train/                  |               |
# |    approx_kl            | 0.00014709635 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.0129        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.06e+05      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000596     |
# |    value_loss           | 4.05e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | -2.88e+04     |
# | time/                   |               |
# |    fps                  | 62            |
# |    iterations           | 6             |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 1536          |
# | train/                  |               |
# |    approx_kl            | 0.00050733075 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.0346        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.6e+04       |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.00193      |
# |    value_loss           | 7.05e+04      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -2.88e+04   |
# | time/                   |             |
# |    fps                  | 52          |
# |    iterations           | 7           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 8.73236e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.000785   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23e+05    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000178   |
# |    value_loss           | 2.5e+05     |
# -----------------------------------------
# SUMO simulation closed.
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1e+03         |
# |    ep_rew_mean          | -3.05e+04     |
# | time/                   |               |
# |    fps                  | 48            |
# |    iterations           | 8             |
# |    time_elapsed         | 42            |
# |    total_timesteps      | 2048          |
# | train/                  |               |
# |    approx_kl            | 0.00013169926 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | -0.000287     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.11e+05      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.00118      |
# |    value_loss           | 4.48e+05      |
# -------------------------------------------
# SUMO simulation closed.
# PPO training completed and model saved successfully.
